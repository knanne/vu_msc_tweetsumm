# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams.update({'font.size': 18})
cycle538 = ["#30a2da","#fc4f30","#e5ae38","#6d904f","#8b8b8b"]

# %%
from scipy import stats

# %% [markdown]
# #### compile summaries for eval

# %%
events = [
    'UEFA Champions League Final',
    'French Open Finals',
    'Monaco Grand Prix',
    'Stanley Cup Playoffs Final Game 7',
    '24 Hours of Le Mans',
    'NBA Playoffs Finals Game 7',
    'The Next Web Conference Europe',
    'Recode Code Conference',
    'Google I/O',
    'Apple Worldwide Developer Conference',
    'Lenovo Tech World',
    'Xbox E3'
    ]

summary_types = [
    'engagements',
    'pr_subevents',
    'pr_e_subevents',
    'prplus_e_subevents'
    ]

data = {}
for event_name in events:
    event_filename = re.sub("\W+", "", event_name.replace('/', '').strip())
    data[event_name] = {}
    for summary_type in summary_types:
        d = pd.read_csv('data/final/summary/foreval_event_%s_summary_%s.txt' % (event_filename, summary_type), sep='\t', encoding='utf-8', header=0, parse_dates=['created_at'], dtype={'twitter_id' : 'str'})
        d['event'] = event_name
        d['summary_type'] = summary_type
        data[event_name][summary_type] = d
        
    df = pd.concat(data[event_name].values())
    data[event_name] = df

allevents = list(data.values())

df = pd.concat(allevents)
df.shape
# Out:
# (1200, 15)

# %%
df.rename(columns={'news' : 'predicted_news'}, inplace=True)

# %% [markdown]
# #### export all summaries file, for annotation

# %%
df.to_csv('data/final/summary/allsummaries_foreval.txt', sep='\t', encoding='utf-8', header=True, index=False)

# %%
df_deduped = df.drop_duplicates(subset='twitter_id')
df_deduped.shape
# Out:
# (886, 15)

# %%
df_deduped.to_csv('data/final/summary/allsummaries_foreval_deduped.txt', sep='\t', encoding='utf-8', header=True, index=False)

# %% [markdown]
# ## import evaled summaries

# %%
df = pd.read_csv('../data/summary/allsummaries_foreval.txt', sep='\t', encoding='utf-8', header=0)
df.shape
# Out:
# (1200, 15)

# %%
#df_evaled = pd.read_csv('../data/summary/manual/allsummaries_evaled.txt', sep='\t', encoding='utf-8', header=0)
df_evaled = pd.read_csv('../data/summary/crowd/tweet_annotations_agg_FINAL.txt', sep='\t', encoding='utf-8', header=0)
df_evaled.shape
# Out:
# (886, 11)

# %% [markdown]
# #### merge summary annotations with summary data

# %%
df.rename(columns={'news' : 'predicted_news'}, inplace=True)

# %%
df = pd.merge(df, df_evaled[['twitter_id', 'news']], on='twitter_id', how='left')
df.shape
# Out:
# (1200, 16)

# %%
df['rank'] = df.apply(lambda x: [x['rank_engagements'], x['rank_subevents']][not np.isnan(x['rank_subevents'])], axis=1)

# %% [markdown]
# #### add event volume

# %%
event_volume = {
    'UEFA Champions League Final' : 192602,
    'French Open Finals' : 23552,
    'Monaco Grand Prix' : 62212,
    'Stanley Cup Playoffs Final Game 7' : 52528,
    '24 Hours of Le Mans' : 31672,
    'NBA Playoffs Finals Game 7': 514439,
    'The Next Web Conference Europe' : 7636,
    'Recode Code Conference' : 5780,
    'Google I/O' : 25533,
    'Apple Worldwide Developer Conference' : 40027,
    'Lenovo Tech World' : 13185,
    'Xbox E3' : 86475
    }

df['event_volume'] = df['event']
df['event_volume'].replace(event_volume, inplace=True)

# %%
event_tweetspermin = {
    'UEFA Champions League Final' : 4387,
    'French Open Finals' : 371,
    'Monaco Grand Prix' : 855,
    'Stanley Cup Playoffs Final Game 7' : 2274,
    '24 Hours of Le Mans' : 386,
    'NBA Playoffs Finals Game 7': 11899,
    'The Next Web Conference Europe' : 20,
    'Recode Code Conference' : 34,
    'Google I/O' : 270,
    'Apple Worldwide Developer Conference' : 449,
    'Lenovo Tech World' : 51,
    'Xbox E3' : 1246
    }

df['event_tweetspermin'] = df['event']
df['event_tweetspermin'].replace(event_tweetspermin, inplace=True)

# %%
event_engagements = {
    'UEFA Champions League Final' : 1157004.0,
    'French Open Finals' : 206522.0,
    'Monaco Grand Prix' : 737306.0,
    'Stanley Cup Playoffs Final Game 7' : 618064.0,
    '24 Hours of Le Mans' : 246008.0,
    'NBA Playoffs Finals Game 7': 2913478.0,
    'The Next Web Conference Europe' : 21634.0,
    'Recode Code Conference' : 51438.0,
    'Google I/O' : 118518.0,
    'Apple Worldwide Developer Conference' : 116413.0,
    'Lenovo Tech World' : 34050.0,
    'Xbox E3' : 339161.0
    }

df['event_engagements'] = df['event']
df['event_engagements'].replace(event_engagements, inplace=True)

# %%
event_domain = {
    'UEFA Champions League Final' : 'Sporting Event',
    'French Open Finals' : 'Sporting Event',
    'Monaco Grand Prix' : 'Sporting Event',
    'Stanley Cup Playoffs Final Game 7' : 'Sporting Event',
    '24 Hours of Le Mans' : 'Sporting Event',
    'NBA Playoffs Finals Game 7': 'Sporting Event',
    'The Next Web Conference Europe' : 'Technology Conference',
    'Recode Code Conference' : 'Technology Conference',
    'Google I/O' : 'Technology Conference',
    'Apple Worldwide Developer Conference' : 'Technology Conference',
    'Lenovo Tech World' : 'Technology Conference',
    'Xbox E3' : 'Technology Conference',
    }

df['event_domain'] = df['event']
df['event_domain'].replace(event_domain, inplace=True)

# %%
new_summary_type = {
    'engagements' : ' Interactions',
    'pr_subevents' : 'CRES0.0',
    'pr_e_subevents' : 'CRES1.0',
    'prplus_e_subevents' : 'CRES2.0',
    }

df['new_summary_type'] = df['summary_type']
df['new_summary_type'].replace(new_summary_type, inplace=True)

# %% [markdown]
# #### compute accurracy
# - running sum
# - total

# %%
df['news_running_sum'] = df.groupby(['summary_type', 'event'])['news'].cumsum()

# %%
df['running_accuracy'] = df['news_running_sum'] / df['rank']

# %%
df['accuracy'] = df.groupby(['event', 'summary_type'])['news'].transform(lambda x: x.sum()) / 25

# %% [markdown]
# #### summary eval sample
# - top 5 tweets in highest scoring summary, for highest scoring events
# - shows crowd annotations, 0's represent strictness

# %%
pd.options.display.max_colwidth = 200

# %%
df[(df['event'].isin(['Monaco Grand Prix', 'Apple Worldwide Developer Conference'])) & (df['summary_type'] == 'pr_subevents') & (df['rank_subevents'] <= 5)].sort_values(by=['event', 'rank_subevents'])[['event', 'rank_subevents', 'twitter_id', 'text', 'news']]
# Out:
#                                     event  rank_subevents          twitter_id  \
# 225  Apple Worldwide Developer Conference             1.0  742423169131155457
# 226  Apple Worldwide Developer Conference             2.0  742412668557004800
# 227  Apple Worldwide Developer Conference             3.0  742409855357583361
# 228  Apple Worldwide Developer Conference             4.0  742412134751993857
# 229  Apple Worldwide Developer Conference             5.0  742419694741639168
# 625                     Monaco Grand Prix             1.0  736904408915677184
# 626                     Monaco Grand Prix             2.0  736920211484487680
# 627                     Monaco Grand Prix             3.0  736919910798987264
# 628                     Monaco Grand Prix             4.0  736893415296798720
# 629                     Monaco Grand Prix             5.0  736904169278296064
#
#                                                                                                                                              text  \
# 225               Messages: 3X bigger emojis and emoji prediction as you type. Easily replace words with emoji. #WWDC2016 https://t.co/GcvdRPEQK2
# 226                                 We love the picture in picture feature! Great for multitasking #macOSSierra #WWDC2016 https://t.co/rbaNoNY9EL
# 227   Cue introduces "Single Sign-On" -- sign in once on Apple TV, and get access to all of your streaming apps. Coming to iOS as well. #WWDC2016
# 228                    Apple Pay is now coming to the web, Safari specifically. Authenticate with TouchID on your iPhone or Apple Watch #WWDC2016
# 229                                                      Lyrics for Apple Music, cool! https://t.co/sv8jBjMMAE  #wwdc2016 https://t.co/p6Fp2p6YRN
# 625                                                                    ...and then Red Bull messed up that pit stop, yes, yes...#TeamLH #MonacoGP
# 626  What a race! What a result 🙈. LONG overdue #MonacoGP win, and what a place to get his 44th win!🏁 Well done @LewisHamilton and @MercedesAMGF1
# 627  Fantastic race by @LewisHamilton, great strategy, perfect drive.. Also my old team mate @SChecoPerez, top drive well done man! #MonacoGP #F1
# 628                                                                                 L7: Safety car in the this lap, we're going racing! #MonacoGP
# 629                   @SkySportsF1 @F1 @redbullracing have cocked up the pit stop for @danielricciardo #monacogp very poor performance there guys
#
#      news
# 225     1
# 226     1
# 227     1
# 228     1
# 229     1
# 625     0
# 626     1
# 627     0
# 628     1
# 629     0

# %%
df[(df['event'].isin(['Monaco Grand Prix', 'Apple Worldwide Developer Conference'])) & (df['summary_type'] == 'prplus_e_subevents') & (df['rank_subevents'] <= 5)].sort_values(by=['event', 'rank_subevents'])[['event', 'rank_subevents', 'twitter_id', 'text', 'news']]
# Out:
#                                     event  rank_subevents          twitter_id  \
# 250  Apple Worldwide Developer Conference             1.0  742423082854277120
# 251  Apple Worldwide Developer Conference             2.0  742412517666783232
# 252  Apple Worldwide Developer Conference             3.0  742409855357583361
# 253  Apple Worldwide Developer Conference             4.0  742419694741639168
# 254  Apple Worldwide Developer Conference             5.0  742425328404992000
# 650                     Monaco Grand Prix             1.0  736904257711026176
# 651                     Monaco Grand Prix             2.0  736920019431477249
# 652                     Monaco Grand Prix             3.0  736920132061147136
# 653                     Monaco Grand Prix             4.0  736893415296798720
# 654                     Monaco Grand Prix             5.0  736904076240297984
#
#                                                                                                                                             text  \
# 250                                     The iMessage app will make it easier to replace yours words with emoji #WWDC2016 https://t.co/oTHVBRgBob
# 251                                                               Say hello to Siri on the Mac. #macOS #Sierra #WWDC2016 https://t.co/pOh8FJD2oG
# 252  Cue introduces "Single Sign-On" -- sign in once on Apple TV, and get access to all of your streaming apps. Coming to iOS as well. #WWDC2016
# 253                                                     Lyrics for Apple Music, cool! https://t.co/sv8jBjMMAE  #wwdc2016 https://t.co/p6Fp2p6YRN
# 254                                        MANY new updates coming to "Messages" + being opened to developers. #WWDC2016 https://t.co/P7pzKycLcy
# 650                          DISASTER for Daniel Ricciardo there. Oh dear.  Red Bull gives you wings, but can't always give you tyres. #MonacoGP
# 651  BREAKING: Lewis Hamilton wins the 2016 #MonacoGP, the 44th victory of his career. Live: https://t.co/wMQuhaILdN #F1 https://t.co/tMiboD1u91
# 652  Chequered flag! Lewis Hamilton wins the Monaco Grand Prix with Daniel Ricciardo in 2nd and Sergio Perez in 3rd! Max sadly retired #MonacoGP
# 653                                                                                L7: Safety car in the this lap, we're going racing! #MonacoGP
# 654             Ricciardo responds ... A very slow stop because they did not have the tires ready!   Disaster in the Red Bull pits #MonacoGP #F1
#
#      news
# 250     0
# 251     0
# 252     1
# 253     1
# 254     1
# 650     0
# 651     1
# 652     1
# 653     1
# 654     1

# %% [markdown]
# #### acuracy

# %%
df.groupby(['event_domain', 'event', 'new_summary_type'])['accuracy'].mean().unstack()
# Out:
# new_summary_type                                             Interactions  \
# event_domain          event
# Sporting Event        24 Hours of Le Mans                            0.40
#                       French Open Finals                             0.44
#                       Monaco Grand Prix                              0.44
#                       NBA Playoffs Finals Game 7                     0.32
#                       Stanley Cup Playoffs Final Game 7              0.28
#                       UEFA Champions League Final                    0.40
# Technology Conference Apple Worldwide Developer Conference           0.24
#                       Google I/O                                     0.24
#                       Lenovo Tech World                              0.24
#                       Recode Code Conference                         0.08
#                       The Next Web Conference Europe                 0.24
#                       Xbox E3                                        0.32
#
# new_summary_type                                            CRES0.0  CRES1.0  \
# event_domain          event
# Sporting Event        24 Hours of Le Mans                      0.32     0.52
#                       French Open Finals                       0.52     0.36
#                       Monaco Grand Prix                        0.44     0.68
#                       NBA Playoffs Finals Game 7               0.12     0.16
#                       Stanley Cup Playoffs Final Game 7        0.32     0.36
#                       UEFA Champions League Final              0.24     0.32
# Technology Conference Apple Worldwide Developer Conference     0.48     0.24
#                       Google I/O                               0.40     0.32
#                       Lenovo Tech World                        0.32     0.40
#                       Recode Code Conference                   0.12     0.12
#                       The Next Web Conference Europe           0.12     0.12
#                       Xbox E3                                  0.28     0.36
#
# new_summary_type                                            CRES2.0
# event_domain          event
# Sporting Event        24 Hours of Le Mans                      0.52
#                       French Open Finals                       0.52
#                       Monaco Grand Prix                        0.68
#                       NBA Playoffs Finals Game 7               0.52
#                       Stanley Cup Playoffs Final Game 7        0.40
#                       UEFA Champions League Final              0.36
# Technology Conference Apple Worldwide Developer Conference     0.60
#                       Google I/O                               0.28
#                       Lenovo Tech World                        0.36
#                       Recode Code Conference                   0.16
#                       The Next Web Conference Europe           0.20
#                       Xbox E3                                  0.24

# %%
title = 'Accuracy by Summary Type for each Event Domain'

fig, ax = plt.subplots(figsize=(12,8))

groups = df.groupby(['event_domain', 'new_summary_type'])['accuracy'].mean()
means = groups.unstack().mean()

groups.unstack().plot(kind='barh', ax=ax)
plt.vlines(x=means.values, ymin=-2, ymax=12, colors=cycle538, linestyle='--')
ax.set_xlim(0,1)

for i,mean in enumerate(means):
    plt.text(mean,1-(i*.5), '%.f%%' % (100*mean))

plt.xlabel('accuracy')
plt.title(title, y=1.1)
plt.legend(markerscale=2, fontsize=18, loc='upper center', bbox_to_anchor=(0.5, 1.1), ncol=4)
fig = plt.gcf()
plt.tight_layout()
plt.show()
fig.savefig('../images/summaryeval_%s.png' % title.replace(' ', '_'))

# %%
title = 'Accuracy by Summary Type for each Event'

groups = df.groupby(['event', 'new_summary_type'])['accuracy'].mean()
means = groups.unstack().mean()

fig, ax = plt.subplots(figsize=(12,8))

ax = groups.unstack().plot(kind='barh', ax=ax, width=.7)
plt.vlines(x=means.values, ymin=-2, ymax=12, colors=cycle538, linestyle='--')
ax.set_xlim(0,1)

for i,mean in enumerate(means):
    plt.text(mean,8-i, '%.f%%' % (100*mean))

plt.xlabel('accuracy')
plt.title(title, y=1.1)
plt.legend(markerscale=2, fontsize=18, loc='upper center', bbox_to_anchor=(0.5, 1.1), ncol=4)
fig = plt.gcf()
plt.tight_layout()
plt.show()
fig.savefig('../images/summaryeval_%s.png' % title.replace(' ', '_'))

# %% [markdown]
# ### visualize

# %%
title = 'Running Sum of News by Summary Rank'

groups = df.groupby('new_summary_type')[['event', 'rank', 'news_running_sum']]

fig, ax = plt.subplots(figsize=(12,8))

for group, dat in groups:
    output = stats.linregress(x=dat['rank'], y=dat['news_running_sum'])
    sns.regplot(data=dat, x='rank', y='news_running_sum', label='%s \nr-value: %s, p-value: %s' % (group, round(output.rvalue,2), round(output.pvalue,2)))

plt.title(title, y=1.3)
plt.legend(markerscale=2, fontsize=18, loc='upper center', bbox_to_anchor=(0.5, 1.3), ncol=2)
fig = plt.gcf()
plt.tight_layout()
plt.show()
fig.savefig('../images/summaryeval_%s.png' % title.replace(' ', '_'))

# %%
title = 'Running Accuracy of Summary per Summary Rank'

groups = df.groupby('new_summary_type')[['event', 'rank', 'running_accuracy']]

fig, ax = plt.subplots(figsize=(12,8))

for group, dat in groups:
    output = stats.linregress(x=dat['rank'], y=dat['running_accuracy'])
    sns.regplot(data=dat, x='rank', y='running_accuracy', label='%s \nr-value: %s, p-value: %s' % (group, round(output.rvalue,2), round(output.pvalue,2)))    

ax.set_ylim(0,1)
    
plt.title(title, y=1.3)
plt.legend(markerscale=2, fontsize=18, loc='upper center', bbox_to_anchor=(0.5, 1.3), ncol=2)
fig = plt.gcf()
plt.tight_layout()
plt.show()
fig.savefig('../images/summaryeval_%s.png' % title.replace(' ', '_'))

# %%
title = 'Total Accuracy of Summary per Event Volume'

groups = df.groupby('new_summary_type')[['event', 'event_volume', 'accuracy']]

fig, ax = plt.subplots(figsize=(12,8))

for group, dat in groups:
    output = stats.linregress(x=dat['event_volume'], y=dat['accuracy'])
    sns.regplot(data=dat, x='event_volume', y='accuracy', label='%s \nr-value: %s, p-value: %s' % (group, round(output.rvalue,2), round(output.pvalue,2)))    

ax.set_ylim(0,1)
    
plt.title(title, y=1.3)
plt.legend(markerscale=2, fontsize=18, loc='upper center', bbox_to_anchor=(0.5, 1.3), ncol=2)
fig = plt.gcf()
plt.tight_layout()
plt.show()
fig.savefig('../images/summaryeval_%s.png' % title.replace(' ', '_'))

# %%
title = 'Total Accuracy of Summary per Event Engagements'

groups = df.groupby('new_summary_type')[['event', 'event_engagements', 'accuracy']]

fig, ax = plt.subplots(figsize=(12,8))

for group, dat in groups:
    output = stats.linregress(x=dat['event_engagements'], y=dat['accuracy'])
    sns.regplot(data=dat, x='event_engagements', y='accuracy', label='%s \nr-value: %s, p-value: %s' % (group, round(output.rvalue,2), round(output.pvalue,2)))    

ax.set_ylim(0,1)
    
plt.title(title, y=1.3)
plt.legend(markerscale=2, fontsize=18, loc='upper center', bbox_to_anchor=(0.5, 1.3), ncol=2)
fig = plt.gcf()
plt.tight_layout()
plt.show()
fig.savefig('../images/summaryeval_%s.png' % title.replace(' ', '_'))
